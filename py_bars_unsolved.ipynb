# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis, bars_in_cities)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
x_tick_value = [xloc for xloc in x_axis]
plt.xticks(x_tick_value,cities)
# Out:
# ([<matplotlib.axis.XTick at 0x22d5286d408>,
#   <matplotlib.axis.XTick at 0x22d5286dec8>,
#   <matplotlib.axis.XTick at 0x22d52489948>,
#   <matplotlib.axis.XTick at 0x22d52b3cb88>,
#   <matplotlib.axis.XTick at 0x22d52b412c8>],
#  [Text(0, 0, 'New Orleans'),
#   Text(1, 0, 'Milwaukee'),
#   Text(2, 0, 'Omaha'),
#   Text(3, 0, 'Pittsburgh'),
#   Text(4, 0, 'Toledo')])

# %%
# Set the limits of the x axis
plt.xlim (-.075,len(x_axis)-.25)
# Out:
# (-0.075, 4.75)

# %%
# Set the limits of the y axis
plt.ylim(4,10)
# Out:
# (4.0, 10.0)

# %%
# Give the chart a title, x label, and y label
plt.xlabel("City Names")
plt.ylabel("Bar values in a city")
plt.title("City Bar Chart")
# Out:
# Text(0.5, 1.0, 'City Bar Chart')

# %%
# Save an image of the chart and print it to the screen
